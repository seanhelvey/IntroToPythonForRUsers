# %% [markdown]
# Jupyter Notebook tips:
# Run a cell: `shift + enter`
# See "Cell" menu option above to run all cells or change cell type from code to markdown.
# See "Insert" menu option above to add cells.
# See "Edit" menu option above to delete cells.
# See "Kernel" menu option to restart and run all output.

# %% [markdown]
# # STEP 1: LOAD PACKAGES & DATA

# %% [markdown]
# ### Load Packages

# %%
# Import Pandas

# %% [markdown]
# ### Read in Data

# %%
# Read the CSV into a dataframe

# Filter to only include Holiday Sweaters

# Display the dataframe
# Out:
#            hs_tf sparkly noise lights objects  \
# sweater
# sweater1     Yes     Yes    No     No      No
# sweater2     Yes      No    No     No      No
# sweater3     Yes      No    No     No      No
# sweater5     Yes      No    No     No      No
# sweater8     Yes      No   Yes    Yes     Yes
# ...          ...     ...   ...    ...     ...
# sweater100   Yes     Yes    No     No     Yes
# sweater103   Yes      No   Yes     No     Yes
# sweater104   Yes     Yes    No     No     Yes
# sweater105   Yes      No    No     No      No
# sweater107   Yes      No    No     No     Yes
#
#                                              colors image_tf  \
# sweater
# sweater1             Red, Yellow, Blue, White, teal      Yes
# sweater2                                      Green       No
# sweater3    Red, Yellow, Green, Brown, White, Black      Yes
# sweater5                         Blue, White, Black      Yes
# sweater8      Red, Green, Blue, Purple, White, Grey       No
# ...                                             ...      ...
# sweater100                     Orange, Yellow, Blue      Yes
# sweater103                Red, Yellow, White, Black      Yes
# sweater104                        Red, White, Black      Yes
# sweater105                   Red, Green, Blue, Grey       No
# sweater107                 Red, Green, White, Black      Yes
#
#                             image_desc
# sweater
# sweater1    octopus dressed like santa
# sweater2                           NaN
# sweater3                        Houses
# sweater5                         T-rex
# sweater8                           NaN
# ...                                ...
# sweater100                     Menorah
# sweater103                       Sloth
# sweater104    R2D2 wearing a Santa hat
# sweater105                         NaN
# sweater107     a llama wearing a scarf
#
# [68 rows x 8 columns]

# %% [markdown]
#  # STEP 2: WRANGLE/PROCESS DATA

# %% [markdown]
# ### Wrangle Colors (The Tidy Way)

# %%
# Make a copy to avoid assignment warnings

# Convert 'colors' column from comma delimited string to list

# Tidy colors data (1 color per row)

# Calc how many colors for each sweater & add to dataframe

# Display the dataframe
# Out:
#            hs_tf sparkly noise lights objects  \
# sweater
# sweater1     Yes     Yes    No     No      No
# sweater2     Yes      No    No     No      No
# sweater3     Yes      No    No     No      No
# sweater5     Yes      No    No     No      No
# sweater8     Yes      No   Yes    Yes     Yes
# ...          ...     ...   ...    ...     ...
# sweater100   Yes     Yes    No     No     Yes
# sweater103   Yes      No   Yes     No     Yes
# sweater104   Yes     Yes    No     No     Yes
# sweater105   Yes      No    No     No      No
# sweater107   Yes      No    No     No     Yes
#
#                                              colors image_tf  \
# sweater
# sweater1             Red, Yellow, Blue, White, teal      Yes
# sweater2                                      Green       No
# sweater3    Red, Yellow, Green, Brown, White, Black      Yes
# sweater5                         Blue, White, Black      Yes
# sweater8      Red, Green, Blue, Purple, White, Grey       No
# ...                                             ...      ...
# sweater100                     Orange, Yellow, Blue      Yes
# sweater103                Red, Yellow, White, Black      Yes
# sweater104                        Red, White, Black      Yes
# sweater105                   Red, Green, Blue, Grey       No
# sweater107                 Red, Green, White, Black      Yes
#
#                             image_desc  \
# sweater
# sweater1    octopus dressed like santa
# sweater2                           NaN
# sweater3                        Houses
# sweater5                         T-rex
# sweater8                           NaN
# ...                                ...
# sweater100                     Menorah
# sweater103                       Sloth
# sweater104    R2D2 wearing a Santa hat
# sweater105                         NaN
# sweater107     a llama wearing a scarf
#
#                                                colors_list  num_colors
# sweater
# sweater1              [Red,  Yellow,  Blue,  White,  teal]           5
# sweater2                                           [Green]           1
# sweater3    [Red,  Yellow,  Green,  Brown,  White,  Black]           6
# sweater5                            [Blue,  White,  Black]           3
# sweater8      [Red,  Green,  Blue,  Purple,  White,  Grey]           6
# ...                                                    ...         ...
# sweater100                        [Orange,  Yellow,  Blue]           3
# sweater103                  [Red,  Yellow,  White,  Black]           4
# sweater104                           [Red,  White,  Black]           3
# sweater105                     [Red,  Green,  Blue,  Grey]           4
# sweater107                   [Red,  Green,  White,  Black]           4
#
# [68 rows x 10 columns]

# %% [markdown]
# ### Wrangle Image Descriptions (The Python / Pandas Way)

# %%
# Replace NaN with empty string

# Convert 'image_desc' column from single space delimited string to list

# Calculate how many image_desc words are present & assign to new column

# Display the dataframe
# Out:
#            hs_tf sparkly noise lights objects  \
# sweater
# sweater1     Yes     Yes    No     No      No
# sweater2     Yes      No    No     No      No
# sweater3     Yes      No    No     No      No
# sweater5     Yes      No    No     No      No
# sweater8     Yes      No   Yes    Yes     Yes
# ...          ...     ...   ...    ...     ...
# sweater100   Yes     Yes    No     No     Yes
# sweater103   Yes      No   Yes     No     Yes
# sweater104   Yes     Yes    No     No     Yes
# sweater105   Yes      No    No     No      No
# sweater107   Yes      No    No     No     Yes
#
#                                              colors image_tf  \
# sweater
# sweater1             Red, Yellow, Blue, White, teal      Yes
# sweater2                                      Green       No
# sweater3    Red, Yellow, Green, Brown, White, Black      Yes
# sweater5                         Blue, White, Black      Yes
# sweater8      Red, Green, Blue, Purple, White, Grey       No
# ...                                             ...      ...
# sweater100                     Orange, Yellow, Blue      Yes
# sweater103                Red, Yellow, White, Black      Yes
# sweater104                        Red, White, Black      Yes
# sweater105                   Red, Green, Blue, Grey       No
# sweater107                 Red, Green, White, Black      Yes
#
#                             image_desc  \
# sweater
# sweater1    octopus dressed like santa
# sweater2
# sweater3                        Houses
# sweater5                         T-rex
# sweater8
# ...                                ...
# sweater100                     Menorah
# sweater103                       Sloth
# sweater104    R2D2 wearing a Santa hat
# sweater105
# sweater107     a llama wearing a scarf
#
#                                                colors_list  num_colors  \
# sweater
# sweater1              [Red,  Yellow,  Blue,  White,  teal]           5
# sweater2                                           [Green]           1
# sweater3    [Red,  Yellow,  Green,  Brown,  White,  Black]           6
# sweater5                            [Blue,  White,  Black]           3
# sweater8      [Red,  Green,  Blue,  Purple,  White,  Grey]           6
# ...                                                    ...         ...
# sweater100                        [Orange,  Yellow,  Blue]           3
# sweater103                  [Red,  Yellow,  White,  Black]           4
# sweater104                           [Red,  White,  Black]           3
# sweater105                     [Red,  Green,  Blue,  Grey]           4
# sweater107                   [Red,  Green,  White,  Black]           4
#
#                             image_desc_list  num_words
# sweater
# sweater1    [octopus, dressed, like, santa]          4
# sweater2                                 []          0
# sweater3                           [Houses]          1
# sweater5                            [T-rex]          1
# sweater8                                 []          0
# ...                                     ...        ...
# sweater100                        [Menorah]          1
# sweater103                          [Sloth]          1
# sweater104   [R2D2, wearing, a, Santa, hat]          5
# sweater105                               []          0
# sweater107    [a, llama, wearing, a, scarf]          5
#
# [68 rows x 12 columns]

# %% [markdown]
# # STEP 3: VISUALIZE DATA

# %%
# Pandas built-in plot tools (which use Matplotlib under the hood)
# This is convenient, but doesn't give as much control as using the Matplotlib API
# Out:
# <AxesSubplot:xlabel='num_colors', ylabel='num_words'>

# %% [markdown]
# ## BONUS: NumPy and Matplotlib API
# There are several ways to visualize our results... most are built on top of the Matplotlib package.

# %%
import matplotlib as mpl
from matplotlib import pyplot as plt

import numpy as np

# Change default plot size
plt.rcParams['figure.figsize'] = (12, 8)

# There are many pre-defined styles... view the available options
print(mpl.style.available)
# or use the default style
plt.style.use('default')
# Out:
# ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
# Matplotlib scatter plot doesn't have built-in jitter option...
# but it's not too hard

def jitterify(arr, factor=0.01):
    """Add jitter 'factor' to 'arr' data
    :param arr: array-like, eg: list, ndarray
    :param factor: float, 0.0 -> 1.0
    :return: arr with added jitter
    """
    assert 0.0 <= factor <= 1.0, f"Error, invalid factor {factor}"
    arr = np.array(arr)
    assert arr.ndim == 1, f"Expected 1-d array, got {arr.ndim}"
    ptp = arr.ptp()
    jitter = np.random.randn(arr.size) * factor * ptp
    return arr + jitter

# %%
# Scatterplot docs:
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.scatter.html

fontsize = 12
markersize = 75
color = '#424242'
alpha = 0.4
jitter = 0.01

# Instantiate plot objects
fig, ax = plt.subplots()

# Add labels to axes
ax.set_xlabel('Number of colors on sweater', fontsize=fontsize, color='k')
ax.set_ylabel('Number of words\nin sweater description', fontsize=fontsize, color='k')
# Add figure title
fig.suptitle("Relationship between the number of colors and\nlength of description for ugly holiday sweaters",
            color='k', fontsize=fontsize + 2)

# Specify what data to plot
x = sweaters.num_colors
y = sweaters.num_words
# Add jitter to data so completely overlapping
x = jitterify(x, jitter)
y = jitterify(y, jitter)

# Plot
ax.scatter(x, y,
            c=color,
            s=markersize,
            alpha=alpha,
            edgecolors=color,
            linewidths=1.
           )

# Add polyfit curve
coeffs = np.polyfit(x, y, 1)
xlim = ax.get_xlim()
ax.plot(xlim, np.polyval(coeffs, xlim), color='k', alpha=0.9)

# Set tick increment
incr_x = 2
incr_y = 5
ax.xaxis.set_major_locator(mpl.ticker.MultipleLocator(incr_x))
ax.yaxis.set_major_locator(mpl.ticker.MultipleLocator(incr_y))

# %% [markdown]
# ### Seaborn library
# This library is designed with data-science and clean asthetics in mind... check it out!<br>
# https://seaborn.pydata.org/
